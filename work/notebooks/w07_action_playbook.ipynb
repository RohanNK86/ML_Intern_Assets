# %% [markdown]
# # ML-10 — Content Action Playbook
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/RohanNK86/ML_Intern_Assets/blob/main/work/notebooks/w07_action_playbook.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Ranked actions + reason codes
#
# *The queue: what to do first, and why, in words a human trusts.*

# %% [markdown]
# **Soln** :
#
# **Action 1**: Refresh Mature Assets (Age 271–365+ Days) — Reason Code: REFRESH_MULTIPLIER. Updating mature evergreen pages yields a 3.2x health score boost (10.7 to 34.5) and a 57x impression lift[cite: 1].
#
# **Action 2:** Snippet & Relevance Refinement for Striking Distance (Positions 4–20) — Reason Code: CTR_CAPTURE. Weighted CTR drops 88% from Top 3 (0.423%) to deep rankings (0.050%)[cite: 1]. Moving striking-distance pages to Top 3 yields faster click conversion than creating new content[cite: 1].
#
# **Action 3:** Target Low-Competition Commercial/Transactional Queries — Reason Code: INTENT_ROI. Transactional low-competition pairings lead portfolio performance with an average health score of 30 and 3.0K average impressions[cite: 1]. Low-competition terms show a 2.1:1 growth-to-decline ratio (62% higher growth probability than high competition)[cite: 1].
#
# **Action : 4** Expand Thin Pages with Existing Visibility (>2,000 Words) — Reason Code: DEPTH_EXPANSION. Content over 5,000 words leads in impressions (8.8K) and AI session share (25.1%)[cite: 1]. Expanding visible pages under 2,000 words protects momentum[cite: 1].
#
# **Action 5:** Consolidate Cannibalizing URLs — Reason Code: CANNIBALIZATION_RISK. Resolves 703.2K cannibalizing queries putting 73.2M search impressions at risk across overlapping content[cite: 1].

# %% [markdown]
# ## 2. Intended use and limits
#
# *Who uses this, for what — and where it stops being valid.*

# %% [markdown]
# **Soln:**
#
# **Intended Use:** Designed for content leads and SEO strategists to prioritize editorial updates, optimize ranking snippets, and allocate writing resources based on empirical lifecycle patterns[cite: 1].
#
# **Operational Limits:**
#
# Observational Guardrails: Findings demonstrate correlation, not direct causal guarantees[cite: 1].
#
# Unindexed Content: Invalid for the 41.8% of portfolio inventory that remains unindexed by search engines[cite: 1].
#
# Metric Scoping: FlyRank Health Score is an internal summary metric (combining impressions, position, CTR, and scroll depth), not an official search engine standard[cite: 1].
#
# Financial Proxies: Captured value relies on click-equivalent proxies (clicks × CPC), not direct booked revenue[cite: 1].

# %% [markdown]
# ## 3. Human review + the no-go list
#
# *What a person must check before acting. What should never be automated.*

# %% [markdown]
# **Soln**
#
# **Required Human Review:** Manual editorial review of factual accuracy, intent match, and internal link structure before republishing updated content[cite: 1]; verification of 301 redirects and canonical tags during cannibalization merges[cite: 1].
#
# **No-Go List (Never Automate):**
#
# Automated word-count padding on pages under 1,000 words without adding subtopics or evidence[cite: 1].
#
# Auto-deleting or auto-redirecting URLs without manual traffic and backlink audits[cite: 1].
#
# Programmatic site-wide auto-refreshing without human editorial oversight[cite: 1].

# %% [markdown]
# ## 4. Monitoring / retrain triggers
#
# *What would tell you the recommendations went stale?*

# %% [markdown]
# **soln:**
#
# **Decay Horizon:** Content reaching 180–270 days post-publication triggers mandatory editorial queueing before reaching the 271–365 day decay cliff[cite: 1].
#
# **CTR Degradation:** A >15% drop in 30-day weighted CTR on Page 1 assets[cite: 1].
#
# **Model Re-estimation:** Portfolio shifts where AI traffic growth alters provider mix (e.g., OpenAI vs. Gemini session distribution) or when quarterly GSC re-indexing occurs[cite: 1].

# %% [markdown]
# ## 5. Exports for the paper
#
# *Write the queue (and any figures you want to reuse) to work/outputs/ — your paper builds on these files.*

# %%
import os
import pandas as pd

# Define action queue based on report findings
action_queue = pd.DataFrame(
    [
        {
            "priority": 1,
            "action": "Refresh mature assets (271-365+ days)",
            "reason_code": "REFRESH_MULTIPLIER",
            "impact_metric": "3.2x Health / 57x Impressions",
        },
        {
            "priority": 2,
            "action": "Refine snippets for striking distance (pos 4-20)",
            "reason_code": "CTR_CAPTURE",
            "impact_metric": "88% CTR drop mitigation",
        },
        {
            "priority": 3,
            "action": "Target low-comp commercial/transactional topics",
            "reason_code": "INTENT_ROI",
            "impact_metric": "2.1:1 Growth Ratio / 30 Health",
        },
        {
            "priority": 4,
            "action": "Expand thin pages with non-zero impressions",
            "reason_code": "DEPTH_EXPANSION",
            "impact_metric": "8.8K Avg Imp / 25.1% AI Share",
        },
        {
            "priority": 5,
            "action": "Consolidate cannibalizing queries",
            "reason_code": "CANNIBALIZATION_RISK",
            "impact_metric": "73.2M Impressions at risk",
        },
    ]
)

os.makedirs("work/outputs", exist_ok=True)
action_queue.to_csv("work/outputs/action_queue.csv", index=False)
print("Action queue successfully exported to work/outputs/action_queue.csv")
# Out:
# Action queue successfully exported to work/outputs/action_queue.csv

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [Done] Every section above is filled — markdown thinking AND the code that backs it
# - [Done] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [Done] No client names, URLs, or private queries anywhere
# - [Done] My claims use careful words: observed, measured, directional, decision-support
# - [Done] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
