# %% [markdown]
# # Capstone — mirrors your deployed research paper
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/RohanNK86/ML_Intern_Assets/blob/main/work/notebooks/capstone.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Question
#
# *The research question and the decision it supports.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
import os

# Define directory structure
structure = [
    'seo-content-intelligence/data/raw',
    'seo-content-intelligence/data/processed',
    'seo-content-intelligence/data/feature_store',
    'seo-content-intelligence/pipelines',
    'seo-content-intelligence/models',
    'seo-content-intelligence/app',
    'seo-content-intelligence/monitoring/evidently_reports',
    'seo-content-intelligence/mlruns',
    'seo-content-intelligence/docker',
    'seo-content-intelligence/github_actions'
]

# Define empty files to create
files = [
    'seo-content-intelligence/pipelines/ingest.py',
    'seo-content-intelligence/pipelines/validate.py',
    'seo-content-intelligence/pipelines/train.py',
    'seo-content-intelligence/pipelines/predict.py',
    'seo-content-intelligence/pipelines/retrain.py',
    'seo-content-intelligence/app/streamlit_app.py',
    'seo-content-intelligence/app/api.py',
    'seo-content-intelligence/monitoring/alerts.py'
]

# Create directories
for folder in structure:
    os.makedirs(folder, exist_ok=True)

# Create empty files
for file_path in files:
    with open(file_path, 'w') as f:
        pass

print('Directory structure and empty files created successfully.')
# !find seo-content-intelligence -maxdepth 3
# Out:
# Directory structure and empty files created successfully.
# seo-content-intelligence
# seo-content-intelligence/monitoring
# seo-content-intelligence/monitoring/evidently_reports
# seo-content-intelligence/monitoring/alerts.py
# seo-content-intelligence/mlruns
# seo-content-intelligence/github_actions
# seo-content-intelligence/docker
# seo-content-intelligence/app
# seo-content-intelligence/app/api.py
# seo-content-intelligence/app/streamlit_app.py
# seo-content-intelligence/data
# seo-content-intelligence/data/feature_store
# seo-content-intelligence/data/processed
# seo-content-intelligence/data/raw
# seo-content-intelligence/data/raw/content_refresh_anonymized.csv
# seo-content-intelligence/pipelines
# seo-content-intelligence/pipelines/validate.py
# seo-content-intelligence/pipelines/retrain.py
# seo-content-intelligence/pipelines/predict.py
# seo-content-intelligence/pipelines/train.py
# seo-content-intelligence/pipelines/ingest.py
# seo-content-intelligence/models

# %% [markdown]
# ## 2. Data
#
# *Which release, which tables, date windows, what you excluded and why. Public-safe.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Methodology
#
# *Assumptions, features, label definition, baseline, validation design, leakage checks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Results (vs baseline)
#
# *Model vs baseline on the same split. The honest table.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Limitations
#
# *What this work cannot claim.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 6. Ranked recommendations
#
# *The action playbook output — the paper's recommendations section.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 7. Artifacts the paper embeds
#
# *Generate/collect the charts and tables your deployed page will show.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
