# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/RohanNK86/ML_Intern_Assets/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# **Answer :** My lane would be the classification, because this meet my interest classifying the information with given features from dataset and predict the accurate values.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# **Answer** : Using the classification i would worked on Email Dataset to classify spam or ham and i would worked with mnist dataset to classify which number is hand written using sparse_categorical_entrophy to train the Neural Network.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# **Answer** : In this  workloads, not only single number will decide the success matric, it depends on the Accuracy, F1 Score, Prediction distribution among each classification.
#
# But Accuracy > 90 Sounds good for average dataset

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.read_csv('/content/content_refresh_anonymized.csv')
df.head(1)
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# 0     20457.0  ...     15000-25000  0.76          10.6             5.88
#
#    scroll_rate  ai_traffic_pct  impression_tier  position_tier  \
# 0         4.55             0.0             good       striking
#
#    trend_direction  trend_pct
# 0             down      -41.4
#
# [1 rows x 44 columns]

# %% [markdown]
# **Solution** : One row in the dataframe represents one webpage (content page) belonging to a client. Each row contains SEO metrics, content information, and performance indicators that can be used to predict whether the page is declining or should be refreshed.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# **Answer** : fixed rule using an if statement checks only a few predefined conditions, which can lead to inaccurate predictions for webpages. Machine learning can analyze many features at the same time, identify complex patterns, and make more accurate predictions, helping users make better content decisions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ Done ] Every section above is filled — markdown thinking AND the code that backs it
# - [ Done ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ Done ] No client names, URLs, or private queries anywhere
# - [ Done ] My claims use careful words: observed, measured, directional, decision-support
# - [ Done ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
